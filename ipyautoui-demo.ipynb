# %% [markdown]
# ---
# title: ipyautoui-demo
# abstract: >
#   rapidly crate user input forms using pydantic
# author: JG
# ---

# %%
from ipyautoui import demo

demo()
# Out:
# DemoReel(children=(VBox(children=(HTML(value='⬇️ -- <b>Select demo pydantic model / generated AutoUi</b> -- ⬇️…

# %%
# Out:
# DemoReel(children=(VBox(children=(HTML(value='⬇️ -- <b>Select demo pydantic model / generated AutoUi</b> -- ⬇️…
